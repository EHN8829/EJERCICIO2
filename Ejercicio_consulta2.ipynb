# %% [markdown]
# <a href="https://colab.research.google.com/github/EHN8829/EJERCICIO2/blob/main/Ejercicio_consulta2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Para jalar un archivo *.csv desde un GitHub
# !wget https://raw.githubusercontent.com/EHN8829/EJERCICIO2/main/scopus2.csv
# Out:
# --2024-08-29 00:32:58--  https://raw.githubusercontent.com/EHN8829/EJERCICIO2/main/scopus2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167235 (163K) [text/plain]
# Saving to: ‘scopus2.csv’
#
# scopus2.csv         100%[===================>] 163.32K  --.-KB/s    in 0.005s
#
# 2024-08-29 00:32:58 (30.9 MB/s) - ‘scopus2.csv’ saved [167235/167235]

# %%
# Para enumerar el contenido de un directorio, se escribe '!ls' en la celda de código y se ejecuta
# !ls
# Out:
# sample_data  scopus2.csv

# %%
# Para abrir el archivo, se usa 'pandas'
import pandas as pd

# %%
# Para colocar como una variable, se usa 'df' (data frame)
df = pd.read_csv('scopus2.csv')

# %%
# Para imprimir como texto
print(df)
# Out:
#                                              Authors  \
# 0                                          Mashat A.
# 1  Bengtsson Bernander K.; Sintorn I.-M.; Strand ...
# 2                   Hao A.; Yuan H.; Hui S.C.; Su J.
# 3  Faridoddin S.; Alexandrovich B.M.; Yurjevich T.O.
# 4  Kumar D.; Li H.; Kumbhar D.D.; Rajbhar M.K.; D...
# 5  Madan S.; Lentzen M.; Brandt J.; Rueckert D.; ...
# 6  Sajiha S.; Radha K.; Venkata Rao D.; Sneha N.;...
# 7  Alshardan A.; Mahgoub H.; Alruwais N.; Darem A...
# 8  Tarquino J.; Rodríguez J.; Becerra D.; Roa-Peñ...
# 9  Moustafa M.H.; Turkey M.S.; Mohamedin N.S.; Da...
#
#                                    Author full names  \
# 0                         Mashat, Arwa (57211476380)
# 1  Bengtsson Bernander, Karl (59198411600); Sinto...
# 2  Hao, Anran (57973586500); Yuan, Haohan (592438...
# 3  Faridoddin, Shariaty (59248784700); Alexandrov...
# 4  Kumar, Dayanand (57199657567); Li, Hanrui (580...
# 5  Madan, Sumit (56888489700); Lentzen, Manuel (5...
# ...

# %%
# Para imprimir como tabla
df
# Out:
#                                              Authors  \
# 0                                          Mashat A.
# 1  Bengtsson Bernander K.; Sintorn I.-M.; Strand ...
# 2                   Hao A.; Yuan H.; Hui S.C.; Su J.
# 3  Faridoddin S.; Alexandrovich B.M.; Yurjevich T.O.
# 4  Kumar D.; Li H.; Kumbhar D.D.; Rajbhar M.K.; D...
# 5  Madan S.; Lentzen M.; Brandt J.; Rueckert D.; ...
# 6  Sajiha S.; Radha K.; Venkata Rao D.; Sneha N.;...
# 7  Alshardan A.; Mahgoub H.; Alruwais N.; Darem A...
# 8  Tarquino J.; Rodríguez J.; Becerra D.; Roa-Peñ...
# 9  Moustafa M.H.; Turkey M.S.; Mohamedin N.S.; Da...
#
#                                    Author full names  \
# 0                         Mashat, Arwa (57211476380)
# 1  Bengtsson Bernander, Karl (59198411600); Sinto...
# 2  Hao, Anran (57973586500); Yuan, Haohan (592438...
# 3  Faridoddin, Shariaty (59248784700); Alexandrov...
# 4  Kumar, Dayanand (57199657567); Li, Hanrui (580...
# 5  Madan, Sumit (56888489700); Lentzen, Manuel (5...
# ...

# %%
# Otro método para para imprimir como tabla llevando a una nueva variable 'ds' y usando el URL del GitHub donde está ubicado el archivo 'scopus.csv'
ds = pd.read_csv('https://raw.githubusercontent.com/EHN8829/EJERCICIO2/main/scopus2.csv')
ds
# Out:
#                                              Authors  \
# 0                                          Mashat A.
# 1  Bengtsson Bernander K.; Sintorn I.-M.; Strand ...
# 2                   Hao A.; Yuan H.; Hui S.C.; Su J.
# 3  Faridoddin S.; Alexandrovich B.M.; Yurjevich T.O.
# 4  Kumar D.; Li H.; Kumbhar D.D.; Rajbhar M.K.; D...
# 5  Madan S.; Lentzen M.; Brandt J.; Rueckert D.; ...
# 6  Sajiha S.; Radha K.; Venkata Rao D.; Sneha N.;...
# 7  Alshardan A.; Mahgoub H.; Alruwais N.; Darem A...
# 8  Tarquino J.; Rodríguez J.; Becerra D.; Roa-Peñ...
# 9  Moustafa M.H.; Turkey M.S.; Mohamedin N.S.; Da...
#
#                                    Author full names  \
# 0                         Mashat, Arwa (57211476380)
# 1  Bengtsson Bernander, Karl (59198411600); Sinto...
# 2  Hao, Anran (57973586500); Yuan, Haohan (592438...
# 3  Faridoddin, Shariaty (59248784700); Alexandrov...
# 4  Kumar, Dayanand (57199657567); Li, Hanrui (580...
# 5  Madan, Sumit (56888489700); Lentzen, Manuel (5...
# ...

# %% [markdown]
# # OTRO EJEMPLO
# ## USANDO SCOPUS3
